# %%
import sklearn.datasets
import sklearn.ensemble
import sklearn.model_selection
import sklearn.svm

import optuna

# %% [markdown]
# Выберем классификатор для нашего приложения, который будет лучше предсказывать.
# На выбор возьмем RandomForestClassifier и SVC. Для определения лучшего из них и подбора гиперпараметров будем использовать optuna.

# %%
def objective(trial):
    iris = sklearn.datasets.load_iris()
    x, y = iris.data, iris.target

    classifier_name = trial.suggest_categorical("classifier", ["SVC", "RandomForest"])
    if classifier_name == "SVC":
        svc_c = trial.suggest_float("svc_c", 1e-10, 1e10, log=True)
        classifier_obj = sklearn.svm.SVC(C=svc_c, gamma="auto", random_state=1)
    else:
        rf_max_depth = trial.suggest_int("rf_max_depth", 2, 32, log=True)
        rf_min_samples_split = trial.suggest_int("rf_max_depth", 2, 12, log=True)
        rf_min_samples_leaf = trial.suggest_int("rf_max_depth", 1, 5, log=True)
        classifier_obj = sklearn.ensemble.RandomForestClassifier(
            max_depth=rf_max_depth, min_samples_split=rf_min_samples_split, min_samples_leaf=rf_min_samples_leaf, 
            random_state=1, n_estimators=100
        )

    score = sklearn.model_selection.cross_val_score(classifier_obj, x, y, n_jobs=-1, cv=5)
    accuracy = score.mean()
    return accuracy



study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
print(study.best_trial)
# Out:
# [I 2020-07-20 13:24:28,012] Finished trial#0 with value: 0.9333333333333333 with parameters: {'classifier': 'SVC', 'svc_c': 3.9287858439559256e-05}. Best is trial#0 with value: 0.9333333333333333.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:28,355] Finished trial#1 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 2}. Best is trial#1 with value: 0.9466666666666665.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:28,697] Finished trial#2 with value: 0.9066666666666666 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 27}. Best is trial#1 with value: 0.9466666666666665.
# [I 2020-07-20 13:24:28,824] Finished trial#3 with value: 0.9333333333333333 with parameters: {'classifier': 'SVC', 'svc_c': 1.043471318877825e-10}. Best is trial#1 with value: 0.9466666666666665.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:29,183] Finished trial#4 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 2}. Best is trial#1 with value: 0.9466666666666665.
# [I 2020-07-20 13:24:29,298] Finished trial#5 with value: 0.9400000000000001 with parameters: {'classifier': 'SVC', 'svc_c': 146699.85099386354}. Best is trial#1 with value: 0.9466666666666665.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:29,720] Finished trial#6 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 6}. Best is trial#1 with value: 0.9466666666666665.
# [I 2020-07-20 13:24:29,837] Finished trial#7 with value: 0.9333333333333333 with parameters: {'classifier': 'SVC', 'svc_c': 6.941324804718297e-06}. Best is trial#1 with value: 0.9466666666666665.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:30,206] Finished trial#8 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 2}. Best is trial#1 with value: 0.9466666666666665.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:30,616] Finished trial#9 with value: 0.9533333333333334 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 3}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:31,020] Finished trial#10 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 6}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:31,399] Finished trial#11 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 2}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:31,786] Finished trial#12 with value: 0.9533333333333334 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 4}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:32,162] Finished trial#13 with value: 0.9533333333333334 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 4}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:32,548] Finished trial#14 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 18}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
# [I 2020-07-20 13:24:32,907] Finished trial#15 with value: 0.9533333333333334 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 4}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:33,248] Finished trial#16 with value: 0.9533333333333334 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 3}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:33,588] Finished trial#17 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 14}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:33,934] Finished trial#18 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 9}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:34,279] Finished trial#19 with value: 0.9533333333333334 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 3}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:34,616] Finished trial#20 with value: 0.9533333333333334 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 3}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:34,962] Finished trial#21 with value: 0.9533333333333334 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 3}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:35,306] Finished trial#22 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 2}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:35,649] Finished trial#23 with value: 0.9533333333333334 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 3}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:35,996] Finished trial#24 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 2}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:36,341] Finished trial#25 with value: 0.9533333333333334 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 4}. Best is trial#9 with value: 0.9533333333333334.
# /home/double_dee/anaconda3/lib/python3.7/site-packages/optuna/trial/_trial.py:722: RuntimeWarning:
#
# Inconsistent parameter values for distribution with name "rf_max_depth"! This might be a configuration mistake. Optuna allows to call the same distribution with the same name more then once in a trial. When the parameter values are inconsistent optuna only uses the values of the first call and ignores all following. Using these values: {'low': 2, 'high': 32, 'step': 1}
#
# [I 2020-07-20 13:24:36,683] Finished trial#26 with value: 0.9466666666666665 with parameters: {'classifier': 'RandomForest', 'rf_max_depth': 8}. Best is trial#9 with value: 0.9533333333333334.
# [I 2020-07-20 13:24:36,792] Finished trial#27 with value: 0.9400000000000001 with parameters: {'classifier': 'SVC', 'svc_c':
. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:51,186] Finished trial#78 with value: 0.9733333333333334 with parameters: {'classifier': 'SVC', 'svc_c': 0.3524814229902732}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:51,293] Finished trial#79 with value: 0.9800000000000001 with parameters: {'classifier': 'SVC', 'svc_c': 0.8832540476734487}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:51,402] Finished trial#80 with value: 0.96 with parameters: {'classifier': 'SVC', 'svc_c': 40.47272949235927}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:51,509] Finished trial#81 with value: 0.9733333333333334 with parameters: {'classifier': 'SVC', 'svc_c': 14.454049044077573}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:51,620] Finished trial#82 with value: 0.96 with parameters: {'classifier': 'SVC', 'svc_c': 45.52313169268181}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:51,729] Finished trial#83 with value: 0.96 with parameters: {'classifier': 'SVC', 'svc_c': 40.8210071699219}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:51,835] Finished trial#84 with value: 0.9733333333333334 with parameters: {'classifier': 'SVC', 'svc_c': 17.190112870169706}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:51,945] Finished trial#85 with value: 0.9733333333333334 with parameters: {'classifier': 'SVC', 'svc_c': 18.194447410565996}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:52,054] Finished trial#86 with value: 0.9333333333333333 with parameters: {'classifier': 'SVC', 'svc_c': 0.0010146309008533018}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:52,166] Finished trial#87 with value: 0.9666666666666668 with parameters: {'classifier': 'SVC', 'svc_c': 26.295400823249125}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:52,271] Finished trial#88 with value: 0.9666666666666668 with parameters: {'classifier': 'SVC', 'svc_c': 26.649462381172615}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:52,380] Finished trial#89 with value: 0.96 with parameters: {'classifier': 'SVC', 'svc_c': 98.29040226541979}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:52,490] Finished trial#90 with value: 0.9533333333333334 with parameters: {'classifier': 'SVC', 'svc_c': 436.185270278459}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:52,599] Finished trial#91 with value: 0.9800000000000001 with parameters: {'classifier': 'SVC', 'svc_c': 2.4153115043349516}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:52,705] Finished trial#92 with value: 0.9800000000000001 with parameters: {'classifier': 'SVC', 'svc_c': 6.217588779220296}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:52,815] Finished trial#93 with value: 0.9800000000000001 with parameters: {'classifier': 'SVC', 'svc_c': 10.167457450300416}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:52,927] Finished trial#94 with value: 0.9800000000000001 with parameters: {'classifier': 'SVC', 'svc_c': 5.024607502093536}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:53,039] Finished trial#95 with value: 0.9800000000000001 with parameters: {'classifier': 'SVC', 'svc_c': 4.425372176956919}. Best is trial#72 with value: 0.9800000000000001.
# [I 2020-07-20 13:24:53,152] Finished trial#96 with value: 0.9866666666666667 with parameters: {'classifier': 'SVC', 'svc_c': 3.6616809069626406}. Best is trial#96 with value: 0.9866666666666667.
# [I 2020-07-20 13:24:53,263] Finished trial#97 with value: 0.9800000000000001 with parameters: {'classifier': 'SVC', 'svc_c': 2.428031129566991}. Best is trial#96 with value: 0.9866666666666667.
# [I 2020-07-20 13:24:53,375] Finished trial#98 with value: 0.9333333333333333 with parameters: {'classifier': 'SVC', 'svc_c': 0.002972266315840536}. Best is trial#96 with value: 0.9866666666666667.
# [I 2020-07-20 13:24:53,489] Finished trial#99 with value: 0.9800000000000001 with parameters: {'classifier': 'SVC', 'svc_c': 2.0874469588915305}. Best is trial#96 with value: 0.9866666666666667.
# FrozenTrial(number=96, value=0.9866666666666667, datetime_start=datetime.datetime(2020, 7, 20, 13, 24, 53, 43039), datetime_complete=datetime.datetime(2020, 7, 20, 13, 24, 53, 151946), params={'classifier': 'SVC', 'svc_c': 3.6616809069626406}, distributions={'classifier': CategoricalDistribution(choices=('SVC', 'RandomForest')), 'svc_c': LogUniformDistribution(high=10000000000.0, low=1e-10)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=96, state=TrialState.COMPLETE)

# %% [markdown]
# Лучшее качество показала модеь SVC с параметром регуляризации C = 3.6616809069626406. Эту модель будем использовать для финального предсказания
